# %% [markdown]
# # Индивидуальное задание

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((-5*n**5+8*n**3-6)/(sqrt(3*n**16+n**7+7)), n, oo))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(((n**3-9*n-2)/(n**3+3*n+9))**(9*n**2+6), n, oo))
# Out:
# exp(-108)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
from sympy import *
n=symbols('n')
print(limit(((-7*n+9)/(-7*n+7))**(3*n-1), n, oo))
# Out:
# exp(-6/7)
