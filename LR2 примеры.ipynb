# %% [markdown]
# # Предел, непрерывность, ряды

# %% [markdown]
# ## Предел, непрерывность

# %%
from sympy import *
x = Symbol("x")
print(limit((6*x**2+3*x)/(3*x**2), x, oo))
# Out:
# 2

# %%
from sympy import *
x = Symbol("X")
print(limit(sin(x)/x, x, 0))
print(limit((1+x)**(1/x), x, 0))
print(limit((1+1/x)**x, x, oo))
# Out:
# 1
# E
# E

# %% [markdown]
# ## Односторонние пределы

# %%
from sympy import *
x = Symbol("X")
print(limit(1/x, x, 0, '-'))
print(limit((2**x-1)/(x**2-3*x), x, 3, '+'))
print(limit((2**x-1)/(x**2-3*x), x, 3, '-'))
# Out:
# -oo
# oo
# -oo

# %%
from sympy import *
x = Symbol("X")
print(limit((5**x-5*7**x)/(4*5**x-3*7**x), x,oo))
print(limit((7*8**x+2*9**x)/(6*8**x-6*9**x), x, -oo))
print(limit(sqrt(x*(x+3))-sqrt(x**2+9), x, -oo))
# Out:
# 5/3
# 7/6
# -3/2

# %%
from sympy import *
x = Symbol("X")
print(limit((5**x-5*7**x)/(4*5**x-3*7**x), x,oo))
print(limit((7*8**x+2*9**x)/(6*8**x-6*9**x), x, -oo))
print(limit(sqrt(x*(x+3))-sqrt(x**2+9), x, -oo))
# Out:
# 5/3
# 7/6
# -3/2

# %%
from sympy import *
x = Symbol("X")
print(solve(x**3-9*x**2+14*x))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 0, '-'))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 0, '+'))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 2, '-'))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 2, '+'))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 7, '-'))
print(limit(abs((x-2)*(x-7)/(x**3-9*x**2+14*x)), x, 7, '+'))
# Out:
# [0, 2, 7]
# oo
# oo
# 1/2
# 1/2
# 1/7
# 1/7

# %%
from sympy import *
x = Symbol("X")
k = limit((1+5*x)/(3+x)/x, x, oo)
print(k)
b = limit((1+5*x)/(3+x)-k*x, x, oo)
print(b)
print(solve(3+x))
print(limit((1+5*x)/(3+x), x, -3, '-'))
print(limit((1+5*x)/(3+x), x, -3, '+'))
# Out:
# 0
# 5
# [-3]
# oo
# -oo

# %% [markdown]
# ## Функциональные ряды

# %%
from sympy import *
import math as m
x = Symbol("X")
print(limit(1/factorial(x)/(1/factorial(x+1)), x, oo))
# Out:
# oo

# %%
import math
from sympy import *
x = Symbol("X")
print(limit(x**x/factorial(x)/((x+1)**(x+1)/factorial(x+1)), x, oo))
# Out:
# exp(-1)

# %%
from sympy import *
x = symbols('x')
func = sin(x)
x0 = 0
print(func.series(x, x0, 10))
# Out:
# x - x**3/6 + x**5/120 - x**7/5040 + x**9/362880 + O(x**10)

# %% [markdown]
# ## Примеры решения задач

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n = sympy.symbols('n')
print(sympy.limit((6*n**2+1)/(7*n**2-3*n+9), n, sympy.oo))
# Out:
# 6/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n = sympy.symbols('n')
print(sympy.limit((-3*n**3+4*n**2-8*n-6)/(4*n**2+2*n), n, sympy.oo))
# Out:
# -oo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sympy
n = sympy.symbols('n')
print(sympy.limit((n**2-3*n)/(-5*n**3+4*n**2+9), n, sympy.oo))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((-7*n+10)/sqrt(9*n**2+10*n),n,oo))
# Out:
# -7/3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((4*n**4-6)/(-2*n**4+8*n**2+9*n-5),n,oo))
# Out:
# -2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((-9*n**5+9*n**4+n**3-8*n)/(7), n, oo))
# Out:
# -oo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((6*n**4+8*n**3+6*n**2-6)/(4*n**6-3*n**5-7*n**4+6*n+9), n, oo))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((8+5*n+cos(6*n))/(3*n-8*sin(5*n)-8),n,oo))
# Out:
# 5/3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit((3+6*n**8+7*cos(3*n))/(6+5*n**3-8*sin(3*n)),n,oo))
# Out:
# zoo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(sqrt(5*n**14-3*n**8+2*n-1)/(2*n**7-8*n**4+1), n, oo))
# Out:
# sqrt(5)/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(sqrt(3*n**18+2)/sqrt(5*n**16-5*n**9+8), n, oo))
# Out:
# oo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
import math as m
import numpy
from numpy import inf
n=symbols('n')
print(limit((7-n+n**2)/(3*n-6)-(2-5*n+n**2)/(3*n+8),n,inf))
# Out:
# 26/9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(2*n-sqrt(4*n**2-5*n+3),n,oo))
# Out:
# 5/4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(sqrt(5*n**2)-sqrt(5*n**2-4), n, oo))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
n=symbols('n')
print(limit(((n**2+3*n+7)/(n**2+8*n-6))**(3*n-4), n, oo))
# Out:
# exp(-15)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit((3*x+9)/(2*cos(2*x)+6*x-3), x, oo))
# Out:
# 1/2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit(1/(sqrt(2*x**2+2*x-3)-sqrt(2*x**2-5*x-5)),x,-oo))
# Out:
# -2*sqrt(2)/7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit((sqrt(x**2+1)-sqrt(x**2+5))*atan(3*x**4-1), x, oo))
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit((4*tan(6*x))/(4*x+3*x**2), x,0))
# Out:
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit(6*sin(9*x)**2/(cos(4*x)-1),x,0))
# Out:
# -243/4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit((1-cos(7/x))/(ln(1+6/x)*(exp(4/x)-1)),x,oo))
# Out:
# 49/48

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import *
x=symbols('x')
print(limit(9*(1-x**(1/7))/(x**(1/8)-1), x, 1))
# Out:
# -10.2857142857143
